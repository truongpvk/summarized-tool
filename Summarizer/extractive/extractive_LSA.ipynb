# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import numpy as np

# %%
def extract_top_n_sentences(sentences: list[str], n: int) -> str:
    if len(sentences) <= n:
        return "This document is not long enough to summary"
    
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(sentences)
    
    svd = TruncatedSVD(n_components=1)
    svd.fit(X)
    
    scores = np.linalg.norm(svd.transform(X), axis=1)

    top_n_indices = np.argsort(scores)[::-1][:n]
    summary = [sentences[i] for i in sorted(top_n_indices)]

    return " ".join(summary)

# %%
import pickle
with open("../../Dataset/extractive/extractive.pk", "rb") as f:
    dataset = pickle.load(f)

dataset
# Out:
# {'Arabic': 0       [يتيح كل موقع من مواقع التواصل الاجتماعي خيارا...
#  1       [قم بتنظيف وغسل الأطباق التي تود تركها ليلًا ف...
#  2       [ليست النظارات المستقطبة من نوع واحد وليس هناك...
#  3       [ليست كل الأرانب ودودة، ولكن إذا كان لديك أرنب...
#  4       [يعتبر هذا أكثر أعراض الاضطراب شيوعًا ووضوحًا,...
#                                ...
#  6042    [ضع الطلاء الرقيق على قطعة من خشب الخردة أو ال...
#  6043    [كان استخدام الأسبستوس شائعًا بين عامي 1920 و1...
#  6044    [يمكنك ربط أي موقع إلكتروني عن طريق نسخ العنوا...
#  6045    [يتعلّم الكلاب من خلال المكافأة على السلوك الإ...
#  6046    [الحصول على دعم اجتماعي يمكن أن يساعد الناس عل...
#  Name: document, Length: 6047, dtype: object,
#  'Chinese': 0       [如果你的礼物接收者居住在寒冷的地方这将留给他一个持久的回忆并且很实用, 。, 如果不知道如...
#  1       [你没有觉得独特是因为每天你都做着相同的陈年旧事, 。, 因此，是时候把事情改变一下了, 。...
#  2       [要进行整鸡去骨的话，你必须先准备好切肉刀等厨用刀具, 。, 要想正确地完成剔骨操作，有一把...
#  3       [虽然可行，但是叶片繁殖法成功的可能性非常渺茫，所以你千万要做好失败的准备, 。,  芦荟叶...
#  4       [如果电脑连接了耳机，那么扬声器是不会有声音的, 。, 插拔耳机可以帮助切换扬声器，解决声音...
#                                ...
#  3709    [为了做调味酱，在中号的壶里加入680g剥皮并洗净的番茄、1个带柄的墨西哥小辣椒、1/2个对...
#  3710    [当气温很低的时候，鲈鱼会到深水区活动, 。, 由于很多钓鱼者在天冷时都会用钓鱼盒，冬天是一...
#  3711    [查看舌头和脸颊内侧是否受到了进一步可能需要看医生的伤害, 。, 如果出现牙齿松动或破损，要...
#  3712    [发现听力下降或出现变化, ？, 约见医疗保健专家，他们可以帮你检查耳朵，看看是否有明显异常...
#  3713    [严格按照衣服的标签上的洗衣要求来, 。,  洗干净后，要自然风干, 。, 用吹风机的热风吹...
#  Name: document, Length: 3714, dtype: object,
#  'Czech': 0       [Vysypejte je ze sáčku a vložte do misky., Dře...
#  1       [Plýtvání vodou patří mezi ty nejhorší způsoby...
#  2       [Zobrazíte ho kliknutím na Connections → Conne...
#  3       [Nejprve led zabalte do ručníku, aby vám z něj...
#  4       [Nemá smysl držet dietu s tím, že budete muset...
#                                ...
#  1409    [Neverbální komunikace je velmi důležitá, poku...
#  1410    [Atkins 20 je aktuální název tradičního progra...
#  1411    [Na začátku 20. století byly velmi populární k...
#  1412    [Usaďte se pohodlně tak, abyste vydrželi alesp...
#  1413    [Jestliže byl váš pes nakažen roztoči způsobuj...
#  Name: document, Length: 1414, dtype: object,
#  'Dutch': 0       [Wanneer je de mogelijkheid hebt om je portfol...
#  1       [Het meest gebruikte materiaal om in deze stij...
#  2       [Hierdoor zal een lijst weergegeven worden met...
#  3       [Vrouwen met overgewicht zijn meer vatbaar voo...
#  4       [Ruim mest, oud stro en gemorst voer op., Als ...
#                                ...
#  6442    [Kussens zijn je beste vrienden wanneer je tij...
#  6443    [Hoe warm je de steiltang instelt mag je zelf ...
#  6444    [Deze ingrediënten maken je huid vetter., Lees...
#  6445    [Gebruik wanneer je je haar in model brengt ge...
#  6446    [Het is normaal dat je de eerste paar weken na...
#  Name: document, Length: 6447, dtype: object,
#  'English': 0        [When learning how to solve a Rubik’s cube, it...
#  1        [The needle will have a cap on it when you pus...
#  2        [One of the best ways to make your friends hap...
#  3        [If your horse has certain anxieties - like cr...
#  4        [It's a white app that contains a multi-colore...
#                                 ...
#  28851    [An inspection is a standard part of any home ...
#  28852    [Several of the most popular cloud storage ser...
#  28853    [The first step to investing is to have availa...
#  28854    [It's in the left sidebar., It's the icon with...
#  28855    [A breakdown can result from trauma or death o...
#  Name: document, Length: 28856, dtype: object,
#  'French': 0        [Tapez https://downloadgram.com/ dans votre na...
#  1        [En plus d'écrire vos pensées négatives et d'y...
#  2        [Pendant les mois les plus chauds, vous devrez...
#  3        [Bien que la capacité à dire « non » soit esse...
#  4        [Pour créer un portail vers le Nether, il vous...
#                                 ...
#  12998    [Il s’agit des produits à base d’huile qui éto...
#  12999    [Mélangez le lait condensé et le sucre dans un...
#  13000    [La pratique quotidienne du yoga peut faire be...
#  13001    [Le bouchon doit bien tenir sur la bouteille, ...
#  13002    [Achetez et portez des vêtements à col V chaqu...
#  Name: document, Length: 13003, dtype: object,
#  'German': 0        [Die richtige Methode anzuwenden, um ein Baby ...
#  1        [Lade deinen Partner zum Abendessen in deiner ...
#  2        [Eine gute Schwimmweste oder -jacke sollte Bru...
#  3        [Deine Melonen werden im Spätsommer und Frühhe...
#  4        [Mache deine Familie auf deine nudistischen Ne...
#                                 ...
#  11773    [Dein Tier kann vielleicht nicht reden, aber e...
#  11774    [Sieh dir im Internet Rezepte an, die das abge...
#  11775    [Ein kreativer, origineller Titel ist eine fan...
#  11776    [Öffne deinen Browser und navigiere auf die Lo...
#  11777    [Kalzium ist das Mineral, das am reichlichsten...
#  Name: document, Length: 11778, dtype: object,
#  'Italian': 0        [Per esempio, se prepari il chutney di mango, ...
#  1        [Digita il nome del profilo della persona che ...
#  2        [Esistono moltissimi siti, applicazioni e comu...
#  3        [Quando tutti gli ospiti hanno finito di mangi...
#  4        [Rivolgiti a un medico o a una clinica per una...
#                                 ...
#  10182    [È caratterizzato da un'icona a forma di "e" b...
#  10183    [Aggiungi al risultato un margine di sicurezza...
#  10184    [Avrai bisogno di alcune informazioni chiave p...
#  10185    [Se hai già eseguito l'accesso al profilo di T...
#  10186    [Se vuoi smettere di parlare, non devi vergogn...
#  Name: document, Length: 10187, dtype: object,
#  'Portuguese': 0        [Existem vários temas de iOS na Google Play St...
#  1        [Escolha um tema que gostaria de conhecer melh...
#  2        [Corte um pedaço de limão ou de lima., Ele dev...
#  3        [Não jogue fora aqueles galhos bonitos que voc...
#  4        [Escolha uma esponja grossa e limpa que seja g...
#                                 ...
#  16381    [Você pode passar algumas contas em linhas e c...
#  16382    [Quando ficar sem nada para fazer, jogar on-li...
#  16383    [Algumas vezes, sentar e não fazer coisa algum...
#  16384    [Embora a maioria dos pequenos furúnculos sare...
#  16385    [Quando ele/ela dorme de barriga para cima, is...
#  Name: document, Length: 16386, dtype: object,
#  'Russian': 0        [После того как вы промокнете матрас и удалите...
#  1        [Не кормите собаку куриными костями или длинны...
#  2        [Ярлык приложения в виде голубого круга с белы...
#  3        [После установки аквариума следует выждать хот...
#  4        [Установите меткое сито над кастрюлей и постел...
#                                 ...
#  10527    [Леггинсы должны покрывать ноги достаточно пло...
#  10528    [Откроется ваш почтовый ящик (если вы вошли в ...
#  10529    [Важный жизненный навык – это способность шути...
#  10530    [Мягкие, гладкие, слегка увлажненные губы идеа...
#  10531    [Если в последнее время (за несколько недель д...
#  Name: document, Length: 10532, dtype: object,
#  'Spanish': 0        [Utiliza una base de cobertura ligera que luzc...
#  1        [Siempre es importante comer de forma saludabl...
#  2        [Este usa gasolina para enfriar tu auto, lo qu...
#  3        [Las tácticas y logística son necesarias, y es...
#  4        [Como los dóberman tienen el pelaje corto, en ...
#                                 ...
#  22762    [Cuela el agua a través de una bandana, una ca...
#  22763    [Evidentemente, la precaución más importante q...
#  22764    [No olvides que todas las niñas menstrúan., De...
#  22765    [El cabello rizado a menudo es más seco que el...
#  22766    [Aplícate un tono más intenso y luminoso sobre...
#  Name: document, Length: 22767, dtype: object,
#  'Turkish': 0      [Âdetinin başlamamasının birçok sebebi vardır....
#  1      [Karıncalar evine girdiğinde, diğer karıncalar...
#  2      [Çoğu zaman termostatik vana, radyatörün alt k...
#  3      [Süpürge ya da elektrikli süpürge kullanarak t...
#  4      [Doğru, bazı doğum kontrol haplarının göğüsler...
#                               ...
#  945    [Etiketin ve kalan yapışkanın çıktığından emin...
#  946    [Bu, PC'nin kayıt defterine erişebileceğin "Ça...
#  947    [Egzersizin, kilo vermeni ve güven kazanmanı s...
#  948    [Bebekler karın üstü oyun oynamayı severler ve...
#  949    [Şu bağlantıyla gidebilirsin: https://www.face...
#  Name: document, Length: 950, dtype: object,
#  'Vietnamese': 0       [Có lẽ bạn quá chú ý vào các vết viêm loét tro...
#  1       [Nhân sâm đỏ Hàn Quốc được cho là có thể tăng ...
#  2       [Mục tiêu của bạn với cách này là phá các chốt...
#  3       [Hãy nhớ rằng: bạn có thể lừa dối bản thân và ...
#  4       [Hầu hết các loại bộ lọc đều cần được làm sạch...
#                                ...
#  4026    [Chuối là một trong các lựa chọn phổ biến nhất...
#  4027    [Nếu bạn lên sân khấu vì đã giành được giải th...
#  4028    [Để thêm tập tin vào thiết bị, bạn cần phải th...
#  4029    [Đầu tiên, bạn hãy xé lớp giấy bạc xung quanh ...
#  4030    [Chạm nút Stickers (Hình dán) ở phía trên màn ...
#  Name: document, Length: 4031, dtype: object}

# %%
summary = extract_top_n_sentences(dataset['Arabic'][0], 3)

# %%
summary
# Out:
# 'قد تحتاج إلى أن تحذف نفسك أو تُلغي حسابك على مواقع التواصل الاجتماعي وقد لا تسعد بفعل ذلك، لكنه في بعض الأحيان حل فعال لكي تمنع ذلك الشخص من الظهور إلى بريد الوارد لديك، احذفه من دفتر العناوين الافتراضي على بريدك واضبط مرشحات الأمان في حسابك التي تحميك من الرسائل غير المفيدة وغير المرغوب فيها، لكي تسمح لك بمراقبة محاولات ذلك الشخص للاتصال بك في حال حاول أن يرسل لك بريدًا إلكترونيًا، يمكنك أن تقوم بحذف رسائله أو أن تجمعها في مجلد خاص في حال احتجت إلى جمع الأدلة إذا كانت مضايقاته ترتقي لذلك المستوى الخطير من البلطجة الإلكترونية أو التحرش قد تحتاج في بعض الأحيان إلى جمع مراسلات ذلك الشخص ومحاولاته للاتصال بك كنوع من الأدلة في حال احتجت إلى مقاضاته في المحكمة، لأن تلك المستندات تدعم قضيتك'
